# %% [markdown]
# <a href="https://colab.research.google.com/github/pr4021622/First-repo-demo/blob/main/Lining_between_star.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.random.rand(100)
y=np.random.rand(100)

# %%
print(x,y)

# %%
plt.plot(x,y)
plt.scatter(x,y)
plt.show()
